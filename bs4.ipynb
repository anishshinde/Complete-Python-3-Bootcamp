# %% [markdown]
# <a href="https://colab.research.google.com/github/anishshinde/Complete-Python-3-Bootcamp/blob/master/bs4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from time import time,sleep
from random import randint
from IPython.core.display import clear_output
from requests import get
from bs4 import BeautifulSoup as soup
import matplotlib.pyplot as plt
import pandas as pd
from urllib.request import urlopen as uReq

# %%
my_url = 'https://www.flipkart.com/televisions/~55-inches-led-tv-/pr?sid=ckf%2Cczl'

# %%
uClient = uReq(my_url)

# %%
page_html = uClient.read()

# %%
page_html
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.fdabe1.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png"/><link rel="app
# ...

# %%
uClient.close()

# %%
page_soup = soup(page_html, "html.parser")

# %%
containers = page_soup.findAll("div",{"class" : "_1UoZlX"})

# %%
containers
# Out:
# []

# %%
containers = page_soup.findAll("div",{"class" : "_1Nyybr _30XEf0"})

# %%
print(len(containers))
# Out:
# 24

# %%
soup.prettify(containers[0])
# Out:
# '<div class="_1UoZlX">\n <a class="_31qSD5" href="/lg-139cm-55-inch-ultra-hd-4k-led-smart-tv/p/itmf6b4g68zggndn?pid=TVSF6B4G7AGUXYAY&amp;lid=LSTTVSF6B4G7AGUXYAYPHX3CH&amp;marketplace=FLIPKART&amp;spotlightTagId=BestvalueId_ckf%2Fczl&amp;srno=b_1_1&amp;otracker=browse&amp;fm=organic&amp;iid=f624fb5e-b6ed-44d3-9656-c39a709cfcab.TVSF6B4G7AGUXYAY.SEARCH&amp;ssid=2mtcbohpvk0000001582797728827" rel="noopener noreferrer" target="_blank">\n  <div>\n  </div>\n  <div class="_3SQWE6">\n   <div class="_1OCn9C">\n    <div>\n     <div class="_3BTv9X" style="height:200px;width:200px">\n      <img alt="LG 139cm (55 inch) Ultra HD (4K) LED Smart TV" class="_1Nyybr" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg"/>\n     </div>\n    </div>\n   </div>\n   <div class="_2lesQu">\n    <div class="_1O_CiZ">\n     <span class="_1iHA1p">\n      <div class="_2kFyHg">\n       <label>\n        <input class="_3uUUD5" readonly="" type="checkbox"/>\n        <div class="_1p7h2j">\n    
# ...

# %%
print(soup.prettify(containers[0]))
# Out:
# <div class="_1UoZlX">
#  <a class="_31qSD5" href="/lg-139cm-55-inch-ultra-hd-4k-led-smart-tv/p/itmf6b4g68zggndn?pid=TVSF6B4G7AGUXYAY&amp;lid=LSTTVSF6B4G7AGUXYAYPHX3CH&amp;marketplace=FLIPKART&amp;spotlightTagId=BestvalueId_ckf%2Fczl&amp;srno=b_1_1&amp;otracker=browse&amp;fm=organic&amp;iid=f624fb5e-b6ed-44d3-9656-c39a709cfcab.TVSF6B4G7AGUXYAY.SEARCH&amp;ssid=2mtcbohpvk0000001582797728827" rel="noopener noreferrer" target="_blank">
#   <div>
#   </div>
#   <div class="_3SQWE6">
#    <div class="_1OCn9C">
#     <div>
#      <div class="_3BTv9X" style="height:200px;width:200px">
#       <img alt="LG 139cm (55 inch) Ultra HD (4K) LED Smart TV" class="_1Nyybr" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg"/>
#      </div>
#     </div>
#    </div>
#    <div class="_2lesQu">
#     <div class="_1O_CiZ">
#      <span class="_1iHA1p">
#       <div class="_2kFyHg">
#        <label>
#         <input class="_3uUUD5" readonly="" type="checkbox"/>
# ...

# %%
container = containers[0]

# %%
container
# Out:
# <div class="_1UoZlX"><a class="_31qSD5" href="/lg-139cm-55-inch-ultra-hd-4k-led-smart-tv/p/itmf6b4g68zggndn?pid=TVSF6B4G7AGUXYAY&amp;lid=LSTTVSF6B4G7AGUXYAYPHX3CH&amp;marketplace=FLIPKART&amp;spotlightTagId=BestvalueId_ckf%2Fczl&amp;srno=b_1_1&amp;otracker=browse&amp;fm=organic&amp;iid=f624fb5e-b6ed-44d3-9656-c39a709cfcab.TVSF6B4G7AGUXYAY.SEARCH&amp;ssid=2mtcbohpvk0000001582797728827" rel="noopener noreferrer" target="_blank"><div></div><div class="_3SQWE6"><div class="_1OCn9C"><div><div class="_3BTv9X" style="height:200px;width:200px"><img alt="LG 139cm (55 inch) Ultra HD (4K) LED Smart TV" class="_1Nyybr" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg"/></div></div></div><div class="_2lesQu"><div class="_1O_CiZ"><span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox"/><div class="_1p7h2j"></div></label></div></span><label class="_10TB-Q"><span>Add to Compare</span></label></div></div><div class="_3gDSOa _32A
# ...

# %%
price = container.findAll("div",{"class" : "_1vC4OE"})

# %%
price[0].text
# Out:
# '₹49,999'

# %%
price
# Out:
# []

# %%
print(price[0].text)
# Out:
# None

# %%
discount = container.findAll("div",{"class" : "VGWI6T"})

# %%
discount
# Out:
# [<div class="VGWI6T"><span>38% off</span></div>]

# %%
print(discount[0].text)
# Out:
# 38% off

# %%
for container in containers:
    price = container.findAll("div",{"class" : "_1vC4OE"})
    print(price[0].text)
# Out:
# ₹49,999
# ₹25,999
# ₹24,999
# ₹42,999
# ₹28,999
# ₹54,999
# ₹21,999
# ₹32,999
# ₹36,999
# ₹45,999
# ₹44,999
# ₹58,999
# ₹44,999
# ₹33,999
# ₹88,999
# ₹34,999
# ₹26,999
# ₹43,499
# ₹25,999
# ₹48,999
# ₹28,499
# ₹39,999
# ₹27,499
# ₹34,999

# %%
for container in containers:
    price = container.findAll("div",{"class" : "_1vC4OE _2rQ-NK"})
    print(price[0].text)
# Out:
# ₹30,999
# ₹35,999
# ₹36,999
# ₹36,999
# ₹28,999
# ₹32,999
# ₹47,999
# ₹27,999
# ₹21,999
# ₹32,999
# ₹82,999
# ₹34,999
# ₹26,999
# ₹21,999
# ₹33,999
# ₹20,999
# ₹54,999
# ₹42,999
# ₹58,999
# ₹22,999
# ₹35,999
# ₹27,499
# ₹60,999
# ₹28,499

# %% [markdown]
# https://developer.mozilla.org/en-US/docs/Web/HTML/Element

# %% [markdown]
# https://2.python-requests.org//en/master/user/quickstart/#make-a-request

# %% [markdown]
# # https://developers.google.com/web/tools/chrome-devtools/dom/

# %%
my_url2 = 'https://www.moneycontrol.com/'

# %%
uClient2 = uReq(my_url2)

# %%
page_html = uClient.read()

# %%
uClient.close()

# %%
page_soup = soup(page_html, "html.parser")

# %%
containers = page_soup.findAll("table",{"class" : "row-1"})

# %%
print(len(containers))
